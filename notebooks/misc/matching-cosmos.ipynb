# %%
import pandas as pd
import sys
import time
from tqdm import tqdm
tqdm.pandas()

from astroquery.irsa import Irsa
from astropy.coordinates import SkyCoord
import astropy.units as u
# Out:
# C:\Users\oryan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: the ``irsa`` module has been moved to astroquery.ipac.irsa, please update your imports.
#   import sys

# %%
folder = 'E:/GZ-DESI/data'

# %%
df_int = pd.read_parquet(f'{folder}/2023-03-15-cats/definitive-merged-interesting-params.parquet', engine = 'pyarrow')

# %% [markdown]
# Catalogue keyword = cosmos2015

# %% [markdown]
# ### Finding a Valid Query

# %%
limits_cosmos = [150.11916667 - 2, 150.11916667 + 2, 2.20583333 - 2, 2.20583333 + 2.20583333]

# %% [markdown]
# I get everything from the Catalogue! The columns I want are:
#
#     1. id - Running Object Number
#     2. SSFR_BEST - The Best Fit log Specific SFR Using BC03 Templates. Taken at the minimum Chi Squared
#     3. SSFR_MED_MAX68 - Upper limit on the 68% Confidence Interval
#     4. SSFR_MED_MIN68 - Lower limit on the 68% confidence interval.
#     5. SSFR_MED - log sSFR from BC03 best-fit template. median of the PDF
#     6. SFR_BEST - log SFR from BC03 best-fit template. Taken at the minimum chi2
#     7. SFR_MED_MAX68 -  upper limit, 68% confidence level
#     8. SFR_MED_MIN68 -  lower limit, 68% confidence level
#     9. SFR_MED -  log sSFR from BC03 best-fit template. median of the PDF
#     10. MASS_BEST - 	 log Stellar mass from BC03 best-fit template
#     11. MASS_MED_MAX68 - 	 upper limit, 68% confidence level
#     12. MASS_MED_MIN68 -  lower limit, 68% confidence level
#     13. MASS_MED - log Stellar mass from BC03 best-fit template. median of the PDF
#     14. AGE -  BC03 age
#     15. TYPE - 	 Type: 0 = galaxy, 1 = star, 2 = X-ray source
#     16. ZPDF - 	 photo-z measured using the galaxy templates
#     17. FLAG_DEEP - 1: Ultra-deep stripes, 0: deep stripes
#     18. FLAG_SHALLOW - Shallow Flag
#     19. l_r - 	 log(dust corr lum in erg/s/Hz) in r filter
#     20. l_k - 	 log(dust corr lum in erg/s/Hz) in NUV filter
#     21. l_nu -  log(dust corr lum in erg/s/Hz) in NUV filter
#     22. dist - I have assumed this is the seperation from my coordinates to the catalogue ones.

# %%
def get_table(ra, dec, reg_limits):
    
    if ra < limits_cosmos[0] or ra > limits_cosmos[1] or dec < limits_cosmos[2] or dec > limits_cosmos[3]:
        return 'outwith_cosmos'
    
    coord = SkyCoord(ra = ra * u.deg, dec = dec * u.deg)
    
    table = Irsa.query_region(coord, catalog = 'cosmos2015', radius = 5 * u.arcsec)
    if len(table) == 0:
        return 'null'
    
    for attempt in range(5):
        try:
            table_df = table.to_pandas().sort_values('dist', ascending = True)
            break
        except:
            time.sleep(5)
    
    if attempt == 4:
        return 'Failed'
    
    table_red = table_df[[
        'id',
        'ssfr_best',
        'ssfr_med_max68',
        'ssfr_med_min68',
        'ssfr_med',
        'sfr_best',
        'sfr_med_max68',
        'sfr_med_min68',
        'sfr_med',
        'mass_best',
        'mass_med_max68',
        'mass_med_min68',
        'mass_med',
        'age',
        'type',
        'zpdf',
        'flag_deep',
        'flag_shallow',
        'l_r',
        'l_k',
        'l_nu',
        'dist',
    ]].iloc[0]
    
    table_dict = table_red.to_dict()
/s]WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
#  91%|█████████ | 179668/197139 [06:58<3:17:49,  1.47it/s]WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
# WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
# WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
#  91%|█████████ | 179668/197139 [07:12<3:17:49,  1.47it/s]WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
#  91%|█████████ | 179672/197139 [07:13<5:09:07,  1.06s/it]WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
#  91%|█████████ | 179673/197139 [07:17<5:45:31,  1.19s/it]WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
# WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
# WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
# WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
#  91%|█████████ | 179673/197139 [07:32<5:45:31,  1.19s/it]WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
#  91%|█████████ | 179682/197139 [07:35<7:15:40,  1.50s/it]WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
#  91%|█████████ | 179683/197139 [07:40<8:04:17,  1.66s/it]WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
# WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
# WARNING: NoResultsWarning: Query returned no results, so the table will be empty [astroquery.ipac.irsa.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results, so the table will be empty
# 100%|██████████| 197139/197139 [07:51<00:00, 417.93it/s]

# %%
results_df = pd.DataFrame.from_dict(results_dict, orient = 'index').reset_index().rename(columns = {'index': 'id_str', 0 : 'matched'})

# %%
df_in_cosmos = results_df.query('matched != "outwith_cosmos" and matched != "null"')

# %%
dict_cosmos = df_in_cosmos[['id_str', 'matched']].set_index('id_str').to_dict()['matched']

# %%
exp_df = pd.DataFrame.from_dict(dict_cosmos, orient = 'index').reset_index().rename(columns = {'index' : 'id_str'})

# %%
exp_df
# Out:
#          id_str         id  ssfr_best  ssfr_med_max68  ssfr_med_min68  \
# 0    341048_283   235022.0    -42.460         -12.532         -12.668
# 1    341048_405   245922.0    -21.221         -13.032         -13.168
# 2    341048_403   246058.0    -19.776         -12.532         -12.668
# 3   342489_2385   442649.0    -12.053         -12.032         -12.168
# 4   345365_4079   837900.0      0.000             NaN             NaN
# 5   345366_3828   843301.0      0.000             NaN             NaN
# 6   343927_4621   678588.0    -13.286         -13.232         -13.368
# 7   346805_3892  1018742.0      0.000             NaN             NaN
# 8   346805_3893  1026511.0      0.000             NaN             NaN
# 9    348245_485  1058803.0    -31.613         -16.175         -16.944
# 10  345368_2400   781167.0    -10.334         -10.224         -10.367
# 11  345368_2333   772647.0    -12.194         -12.131         -12.268
# 12  345369_2736   786830.0    -11.668         -11.632         -11.768
# 13  346807_3896  1004150.0    -17.742         -11.932         -12.068
# 14   348248_160  1044256.0    -10.475         -10.433         -10.570
# 15  346808_3414   974466.0    -19.054         -12.532         -12.668
# 16  343930_3971   668237.0    -31.613         -12.230         -16.941
# 17  343930_3551   652611.0    -38.121         -12.532         -12.668
# 18  343930_3862   665718.0    -12.449         -12.325         -12.471
# 19  343931_4505   697527.0    -12.194         -12.111         -12.260
# 20   346810_963   908372.0      0.000             NaN             NaN
#
#     ssfr_med  sfr_best  sfr_med_max68  sfr_med_min68  sfr_med  ...  mass_med  \
# 0    -12.600   -31.311         -1.432         -1.568   -1.500  ...    11.150
# 1    -13.100   -10.030         -1.832         -1.968   -1.900  ...    11.150
# 2    -12.600    -8.535         -1.332         -1.468   -1.400  ...    11.250
# 3    -12.100    -0.685         -0.632         -0.768   -0.700  ...    11.350
# 4        NaN       NaN            NaN            NaN      NaN  ...       NaN
# 5        NaN       NaN            NaN            NaN      NaN  ...       NaN
# 6    -13.300    -2.488         -2.432         -2.568   -2.500  ...    10.800
# 7        NaN       NaN            NaN            NaN      NaN  ...       NaN
# 8        NaN       NaN            NaN            NaN      NaN  ...       NaN
# 9    -16.826   -20.484         -5.075         -5.744   -5.626  ...    11.141
# 10   -10.295     0.639          0.676          0.534    0.605  ...    10.948
# 11   -12.200    -0.608         -0.531         -0.668   -0.600  ...    11.600
# 12   -11.700    -0.324         -0.232         -0.368   -0.300  ...    11.400
# 13   -12.000    -7.757         -1.832         -1.968   -1.900  ...    10.100
# 14   -10.502    -0.148         -0.032         -0.168   -0.100  ...    10.351
# 15   -12.600    -7.875         -1.332         -1.468   -1.400  ...    11.200
# 16   -16.815   -20.511         -1.030         -5.741   -5.615  ...    11.148
# 17   -12.600   -26.760         -1.132         -1.268   -1.200  ...    11.400
# 18   -12.398    -1.595         -1.525         -1.671   -1.598  ...    10.848
# 19   -12.179    -1.253         -1.055         -1.260   -1.174  ...    11.003
# 20       NaN       NaN            NaN            NaN      NaN  ...       NaN
#
#              age  type   zpdf  flag_deep  flag_shallow     l_r     l_k  \
# 0   8.000000e+09   0.0  0.210        0.0           0.0  29.530  29.933
# 1   9.000000e+09   0.0  0.220        0.0           0.0  29.540  29.956
# 2   8.000000e+09   0.0  0.210        0.0           0.0  29.630  30.030
# 3   1.000000e+10   2.0  0.302        1.0           0.0  29.853  30.150
# 4            NaN  -9.0    NaN        0.0           0.0     NaN     NaN
# 5            NaN   1.0    NaN        0.0           1.0     NaN     NaN
# 6   3.500000e+09   0.0  0.330        1.0           0.0  29.490  29.835
# 7            NaN   0.0    NaN        0.0           0.0     NaN     NaN
# 8            NaN   0.0    NaN        0.0           0.0     NaN     NaN
# 9   5.500000e+09   0.0  0.330        0.0           0.0  29.628  29.995
# 10  8.000000e+09   0.0  0.250        1.0           0.0  29.622  29.909
# 11  8.000000e+09   2.0  0.380        0.0           0.0  30.017  30.401
# 12  9.000000e+09   2.0  0.339        0.0           1.0  29.880  30.163
# 13  2.300000e+09   0.0  0.163        0.0           0.0  28.804  29.094
# 14  4.000000e+09   0.0  0.180        0.0           0.0  29.106  29.389
# 15  7.500000e+09   0.0  0.295        0.0           0.0  29.589  29.979
# 16  5.500000e+09   0.0  0.320        0.0           1.0  29.602  29.968
# 17  7.000000e+09   0.0  0.350        0.0           1.0  29.784  30.167
# 18  1.100000e+10   0.0  0.181        0.0           1.0  29.203  29.617
# 19  8.000000e+09   0.0  0.170        0.0           1.0  29.372  29.756
# 20           NaN  -9.0    NaN        0.0           1.0     NaN     NaN
#
#       l_nu      dist
# 0   26.985  0.153464
# 1   26.990  0.185488
# 2   27.087  0.151886
# 3   27.895  0.601622
# 4      NaN  0.030736
# 5      NaN  0.031042
# 6   27.227  0.057584
# 7      NaN  0.071490
# 8      NaN  0.062083
# 9   27.144  0.032961
# 10  28.765  0.700157
# 11  27.815  0.226988
# 12  28.098  0.139061
# 13  26.704  0.096855
# 14  28.014  0.093277
# 15  27.049  0.512183
# 16  27.117  0.067128
# 17  27.243  0.098642
# 18  26.907  0.105088
# 19  27.169  0.049081
# 20     NaN  0.577695
#
# [21 rows x 23 columns]

# %%
full_df = exp_df.merge(df_int, on = 'id_str', how = 'left')

# %%
len(full_df)
# Out:
# 21

# %%
full_df_dedup = full_df.drop_duplicates('id', keep = 'first')

# %%
len(full_df_dedup)
# Out:
# 21

# %%
full_df_dedup.to_csv('C:/Users/oryan/Documents/mergers_in_desi/data/desi-cosmos-matched-df.csv')
